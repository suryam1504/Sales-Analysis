# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# ## Task #1 - Merging 12 months of sales data into a single file

# %%
# Referenced - https://stackoverflow.com/questions/3207219/how-do-i-list-all-files-of-a-directory
files = [file for file in os.listdir(r'C:\Users\surya\Desktop\Jupyter Python Programs\Sales Analysis\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]

for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
# Concatenating all the above 12 files

all_months_df = pd.DataFrame()

for file in files:
    each_month_df = pd.read_csv('C:\\Users\\surya\\Desktop\\Jupyter Python Programs\\Sales Analysis\\Pandas-Data-Science-Tasks-master\\SalesAnalysis\\Sales_Data\\' + file)
    all_months_df = pd.concat([all_months_df, each_month_df])

# %%
all_months_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
# Exporting it to check if the excel file has all 12 months merged now (it has!)
all_months_df.to_csv(r'C:\Users\surya\Desktop\Jupyter Python Programs\Sales Analysis\Pandas-Data-Science-Tasks-master\SalesAnalysis\All_Months_Merged_Data.csv', index=False)

# %% [markdown]
# ### Reading in the updated dataframe

# %%
df = pd.read_csv(r'C:\Users\surya\Desktop\Jupyter Python Programs\Sales Analysis\Pandas-Data-Science-Tasks-master\SalesAnalysis\All_Months_Merged_Data.csv')

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ## Task #2 - Cleaning Data, i.e. Dropping NaN values

# %%
# Referenced - https://stackoverflow.com/questions/43424199/display-rows-with-one-or-more-nan-values-in-pandas-dataframe
nan_df = df[df.isnull().any(axis=1)]
nan_df
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# ...

# %%
# Dropping these rows
df.dropna(how='all', inplace=True)

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
# Resetting the index
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ## Summary and Statistics

# %%
df.shape
# Out:
# (186305, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186305 entries, 0 to 186304
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %% [markdown]
# # Question #1 - What was the best month for sales? How much was earned that month?

# %% [markdown]
# ## Task #3 - Adding Month Column

# %%
df['Month'] = df['Order Date'].str[0:2]

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
# Converting these values from string to integer
# df['Month'] = df['Month'].astype('int32')      # this gives error that cannot convert string 'Or' to int

# %% [markdown]
# ### Finding 'Or' and deleting those rows

# %%
df[df['Month'] == 'Or']
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 517     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1146    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1152    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2869    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2884    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 184624  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185009  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186019  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186088  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186194  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month
# 517     Purchase Address    Or
# 1146    Purchase Address    Or
# 1152    Purchase Address    Or
# ...

# %%
# Dropping these rows
df.drop(df[df['Month'] == 'Or'].index, inplace=True)

# %%
df[df['Month'] == 'Or']     # all such rows dropped
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Month]
# Index: []

# %%
# Converting these values from string to integer
df['Month'] = df['Month'].astype('int32')

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ## Task #4 - Adding Sales Column

# %%
# df['Sales'] = df['Quantity Ordered'] * df['Price Each']    # TypeError: can't multiply sequence by non-int of type 'str'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186304
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
# dtypes: int32(1), object(6)
# memory usage: 10.6+ MB

# %% [markdown]
# We can see that Quantity Ordered and Price Each are objects (strings or mixed datatypes) and we need to convert them into int and float respectively.

# %% [markdown]
# ### Converting columns to correct datatype

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])

# %%
df['Price Each'] = pd.to_numeric(df['Price Each'])

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
# Rearranging columns
df = df[['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Sales', 'Order Date', 'Month', 'Purchase Address']]

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#        Order Date  Month                      Purchase Address
# 0  04/19/19 08:46      4          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30      4     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27      4     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ### Answering the question

# %%
month_grp = df.groupby('Month')

# %%
month_grp.sum()
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
# Explicitly for Sales column
month_grp['Sales'].sum()
# Out:
# Month
# 1     1.822257e+06
# 2     2.202022e+06
# 3     2.807100e+06
# 4     3.390670e+06
# 5     3.152607e+06
# 6     2.577802e+06
# 7     2.647776e+06
# 8     2.244468e+06
# 9     2.097560e+06
# 10    3.736727e+06
# 11    3.199603e+06
# 12    4.613443e+06
# Name: Sales, dtype: float64

# %% [markdown]
# ### Plotting a bar chart

# %%
import matplotlib.pyplot as plt

# %%
months = range(1,13)
results = month_grp['Sales'].sum()

# Referenced - https://stackoverflow.com/questions/23490626/how-to-avoid-axis-values-with-1e7-in-pandas-and-matplotlib
plt.ticklabel_format(style = 'plain')  # shows values in millions on y-axis instead of simply printing 1,2,3..... and 1e6

plt.bar(months, results)
plt.xticks(months)
plt.ylabel('Sales in US Dollars')
plt.xlabel('Month')
plt.show()

# %% [markdown]
# ### Conclusion - Clearly, most sales were made in December (4.6 million) and least in January.

# %% [markdown]
# # Question #2 - Which city had the highest number of sales?

# %% [markdown]
# ## Task #5 - Adding a city and state column

# %%
df['City'] = df['Purchase Address'].str.split(',', expand=True)[1]

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#        Order Date  Month                      Purchase Address          City
# 0  04/19/19 08:46      4          917 1st St, Dallas, TX 75001        Dallas
# 1  04/07/19 22:30      4     682 Chestnut St, Boston, MA 02215        Boston
# 2  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# 3  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# 4  04/30/19 09:27      4     333 8th St, Los Angeles, CA 90001   Los Angeles

# %% [markdown]
# Another Method - df['City'] = df['Purchase Address'].apply(lambda x: x.split(',')[1])

# %%
# The city Portland is in both Oregon and Maine states, so we also need to mention state in our city column
df['State'] = df['Purchase Address'].apply(lambda x: x.split(',')[2])

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#        Order Date  Month                      Purchase Address          City  \
# 0  04/19/19 08:46      4          917 1st St, Dallas, TX 75001        Dallas
# 1  04/07/19 22:30      4     682 Chestnut St, Boston, MA 02215        Boston
# 2  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# 3  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# 4  04/30/19 09:27      4     333 8th St, Los Angeles, CA 90001   Los Angeles
#
#        State
# 0   TX 75001
# ...

# %%
df['State'] = df['State'].str[0:3]

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#        Order Date  Month                      Purchase Address          City  \
# 0  04/19/19 08:46      4          917 1st St, Dallas, TX 75001        Dallas
# 1  04/07/19 22:30      4     682 Chestnut St, Boston, MA 02215        Boston
# 2  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# 3  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# 4  04/30/19 09:27      4     333 8th St, Los Angeles, CA 90001   Los Angeles
#
#   State
# 0    TX
# 1    MA
# 2    CA
# ...

# %%
df['City'] = df['City'] + ' ' + '(' + df['State'] + ')'

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#        Order Date  Month                      Purchase Address  \
# 0  04/19/19 08:46      4          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30      4     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27      4     333 8th St, Los Angeles, CA 90001
#
#                  City State
# 0        Dallas ( TX)    TX
# 1        Boston ( MA)    MA
# 2   Los Angeles ( CA)    CA
# ...

# %%
df.drop(columns = 'State', inplace=True)

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#        Order Date  Month                      Purchase Address  \
# 0  04/19/19 08:46      4          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30      4     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38      4  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27      4     333 8th St, Los Angeles, CA 90001
#
#                  City
# 0        Dallas ( TX)
# 1        Boston ( MA)
# 2   Los Angeles ( CA)
# 3   Los Angeles ( CA)
# ...

# %% [markdown]
# ### Answering the question

# %%
city_grp = df.groupby('City')

# %%
city_grp['Sales'].sum()
# Out:
# City
#  Atlanta ( GA)          2.795499e+06
#  Austin ( TX)           1.819582e+06
#  Boston ( MA)           3.661642e+06
#  Dallas ( TX)           2.767975e+06
#  Los Angeles ( CA)      5.452571e+06
#  New York City ( NY)    4.664317e+06
#  Portland ( ME)         4.497583e+05
#  Portland ( OR)         1.870732e+06
#  San Francisco ( CA)    8.262204e+06
#  Seattle ( WA)          2.747755e+06
# Name: Sales, dtype: float64

# %% [markdown]
# ### Plotting Bar Chart

# %%
cities = [city for city, df in df.groupby('City')]
results1 = city_grp['Sales'].sum()

plt.ticklabel_format(style = 'plain')      

plt.bar(cities, results1)
plt.xticks(cities, rotation = 'vertical', size = 10)
plt.ylabel('Sales in US Dollars')
plt.xlabel('US City')
plt.show()

# %% [markdown]
# ### Conclusion - San Francisco made the most sales (8 million dollars).

# %% [markdown]
# # Question #3 - What time should advertisements be displayed to maximize likelihood of customer's buying products?

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#            Order Date  Month                      Purchase Address  \
# 0 2019-04-19 08:46:00      4          917 1st St, Dallas, TX 75001
# 1 2019-04-07 22:30:00      4     682 Chestnut St, Boston, MA 02215
# 2 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 3 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-30 09:27:00      4     333 8th St, Los Angeles, CA 90001
#
#                  City
# 0        Dallas ( TX)
# 1        Boston ( MA)
# 2   Los Angeles ( CA)
# ...

# %%
df['Hour'] = df['Order Date'].dt.hour
df['Minute'] = df['Order Date'].dt.minute

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#            Order Date  Month                      Purchase Address  \
# 0 2019-04-19 08:46:00      4          917 1st St, Dallas, TX 75001
# 1 2019-04-07 22:30:00      4     682 Chestnut St, Boston, MA 02215
# 2 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 3 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-30 09:27:00      4     333 8th St, Los Angeles, CA 90001
#
#                  City  Hour  Minute
# 0        Dallas ( TX)     8      46
# ...

# %% [markdown]
# ### Plotting Line Graph

# %%
hours = [hour for hour, df in df.groupby('Hour')]

plt.plot(hours, df.groupby('Hour').count()['Sales'])

plt.xticks(hours)
plt.grid()

plt.xlabel('Hour')
plt.ylabel('Number of Orders')

plt.show()

# %% [markdown]
# ### Conclusion - Seeing the peaks, around 1100 and 1200 hours (11am and 12pm) and 1900 hours (7pm) would be the best timing for displaying advertisements.

# %%
# df.groupby('Hour').count()

# %% [markdown]
# # Question #4 - What products are most often sold together?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#            Order Date  Month                      Purchase Address  \
# 0 2019-04-19 08:46:00      4          917 1st St, Dallas, TX 75001
# 1 2019-04-07 22:30:00      4     682 Chestnut St, Boston, MA 02215
# 2 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 3 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-30 09:27:00      4     333 8th St, Los Angeles, CA 90001
#
#                  City  Hour  Minute
# 0        Dallas ( TX)     8      46
# ...

# %% [markdown]
# We can see index 2 and 3 have the same Order Id and were also delivered to the same address, that means these 2 products were sold together.

# %%
# to see all the rows with duplicated Order ID
df[df['Order ID'].duplicated(keep=False)]   # keep=False considers all similar values as duplicates
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 17       176574                Google Phone                 1      600.00
# 18       176574        USB-C Charging Cable                 1       11.95
# 29       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186248   259303       AA Batteries (4-pack)                 1        3.84
# 186259   259314            Wired Headphones                 1       11.99
# 186260   259314      AAA Batteries (4-pack)                 2        2.99
# 186296   259350                Google Phone                 1      600.00
# 186297   259350        USB-C Charging Cable                 1       11.95
#
#          Sales          Order Date  Month  \
# ...

# %%
# Assigning this to a new dataframe duplicate_df
duplicate_df = df[df['Order ID'].duplicated(keep=False)]

# %%
duplicate_df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 2     176560                Google Phone                 1      600.00
# 3     176560            Wired Headphones                 1       11.99
# 17    176574                Google Phone                 1      600.00
# 18    176574        USB-C Charging Cable                 1       11.95
# 29    176585  Bose SoundSport Headphones                 1       99.99
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176586      AAA Batteries (4-pack)                 2        2.99
# 32    176586                Google Phone                 1      600.00
# 118   176672    Lightning Charging Cable                 1       14.95
# 119   176672        USB-C Charging Cable                 1       11.95
# 128   176681    Apple Airpods Headphones                 1      150.00
# 129   176681             ThinkPad Laptop                 1      999.99
# ...

# %%
# Getting all the products of a particular Order ID in one line
duplicate_df['Grouped'] = duplicate_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
# Out:
# <ipython-input-60-e2bb19647221>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate_df['Grouped'] = duplicate_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
duplicate_df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 2     176560                Google Phone                 1      600.00
# 3     176560            Wired Headphones                 1       11.99
# 17    176574                Google Phone                 1      600.00
# 18    176574        USB-C Charging Cable                 1       11.95
# 29    176585  Bose SoundSport Headphones                 1       99.99
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176586      AAA Batteries (4-pack)                 2        2.99
# 32    176586                Google Phone                 1      600.00
# 118   176672    Lightning Charging Cable                 1       14.95
# 119   176672        USB-C Charging Cable                 1       11.95
# 128   176681    Apple Airpods Headphones                 1      150.00
# 129   176681             ThinkPad Laptop                 1      999.99
# ...

# %%
# Dropping duplicated Order ID
duplicate_df = duplicate_df[['Order ID', 'Grouped']].drop_duplicates()

# %%
duplicate_df.head(20)
# Out:
#     Order ID                                            Grouped
# 2     176560                      Google Phone,Wired Headphones
# 17    176574                  Google Phone,USB-C Charging Cable
# 29    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 31    176586                AAA Batteries (4-pack),Google Phone
# 118   176672      Lightning Charging Cable,USB-C Charging Cable
# 128   176681           Apple Airpods Headphones,ThinkPad Laptop
# 137   176689  Bose SoundSport Headphones,AAA Batteries (4-pack)
# 188   176739                34in Ultrawide Monitor,Google Phone
# 224   176774      Lightning Charging Cable,USB-C Charging Cable
# 232   176781                    iPhone,Lightning Charging Cable
# 249   176797  Google Phone,Bose SoundSport Headphones,Wired ...
# 259   176805                  Google Phone,USB-C Charging Cable
# 263   176808                      Google Phone,Wired Headphones
# 269   176813                      Google Phone,Wired Headphones
# ...

# %%
# Now to count the pairs which occur most 

# Referenced - https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary

from itertools import combinations
from collections import Counter

# %%
count = Counter()

for row in duplicate_df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

# %%
count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### Conclusion - Iphone and Lightning Charging Cable were the 2 products sold together the most.

# %% [markdown]
# # Question #5 - What Product was sold the most?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each   Sales  \
# 0   176558        USB-C Charging Cable                 2       11.95   23.90
# 1   176559  Bose SoundSport Headphones                 1       99.99   99.99
# 2   176560                Google Phone                 1      600.00  600.00
# 3   176560            Wired Headphones                 1       11.99   11.99
# 4   176561            Wired Headphones                 1       11.99   11.99
#
#            Order Date  Month                      Purchase Address  \
# 0 2019-04-19 08:46:00      4          917 1st St, Dallas, TX 75001
# 1 2019-04-07 22:30:00      4     682 Chestnut St, Boston, MA 02215
# 2 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 3 2019-04-12 14:38:00      4  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-30 09:27:00      4     333 8th St, Los Angeles, CA 90001
#
#                  City  Hour  Minute
# 0        Dallas ( TX)     8      46
# ...

# %%
product_grp = df.groupby('Product')

# %%
product_grp['Product'].count()    # no. of times say, 20in Monitor occurs in our dataframe
# Out:
# Product
# 20in Monitor                   4101
# 27in 4K Gaming Monitor         6230
# 27in FHD Monitor               7507
# 34in Ultrawide Monitor         6181
# AA Batteries (4-pack)         20577
# AAA Batteries (4-pack)        20641
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# Flatscreen TV                  4800
# Google Phone                   5525
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      21658
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# USB-C Charging Cable          21903
# Vareebadd Phone                2065
# Wired Headphones              18882
# iPhone                         6842
# Name: Product, dtype: int64

# %%
product_grp.sum()['Quantity Ordered']    # maybe someone ordered 2 or 3 or 4 20in Monitor, so their sum, that's why all values here are greater than the above output
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %% [markdown]
# ### Plotting a bar chart

# %%
quantity_ordered = product_grp.sum()['Quantity Ordered']
products = [product for product, df in df.groupby('Product')]     

plt.bar(products, quantity_ordered)

plt.xticks(products, rotation = 'vertical', size = 10)
plt.ylabel('Sum of Quantities Ordered')
plt.xlabel('Product Name')

plt.show()

# %% [markdown]
# ### Conclusion - AAA Batteries (4-pack) were sold the most, followed by AA Batteries, Charging Cable and Wired Headphones, reason probably being these are cheap and basic items everyone needs.

# %% [markdown]
# # Plotting the above graph with prices of each product

# %%
prices = df.groupby('Product').mean()['Price Each']

# %%
prices
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
# Referenced - https://stackoverflow.com/questions/14762181/adding-a-y-axis-label-to-secondary-y-axis-in-matplotlib

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, quantity_ordered, color='g')
ax2.plot(products, prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Sum of Quantities Ordered', color='g')
ax2.set_ylabel('Price of Product', color='b')

ax1.set_xticklabels(products, rotation = 'vertical', size=10)

plt.show()
# Out:
# <ipython-input-75-85cda683ab3e>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation = 'vertical', size=10)

# %% [markdown]
# ### Conclusion - Majorly, products with less price have more quantity ordered.
